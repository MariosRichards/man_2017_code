# %%
import numpy as np
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt
import gc
import re

from sklearn import datasets
from sklearn.decomposition import PCA
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.preprocessing import StandardScaler

# %%
# %%time
# Load BES Panel for Wave 8
parsed_data = pd.read_pickle("man_of_2017_parsed.pkl")
#(31409, 733)

# BES_Panel = pd.read_stata("../BES_analysis_data/BES2015_W8_v1.6.dta")

print( parsed_data.shape )
# Out:
# (313, 83)
# Wall time: 12 ms

# %%
discrete_only = pd.DataFrame()
for col in parsed_data.columns:
    # drop object and datetime64[ns] silently
    if str( parsed_data[col].dtype ) == 'category':
        discrete_only[col] = parsed_data[col].cat.codes.astype('float')
    elif ( str( parsed_data[col].dtypes ) == 'bool'):
        discrete_only[col] = parsed_data[col].astype('float')
    elif ( str( parsed_data[col].dtypes ) == 'int64' ):
        discrete_only[col] = (parsed_data[col]>0).astype('float')

# %%
discrete_only.to_stata("man2017_discrete.dta")

# %%
strengths = pd.read_csv("strengths_discrete2017man.csv")
str_df = strengths.drop('Unnamed: 0',axis=1).sort_values(by="strength")

# %%
str_df
# Out:
#                                 from                               to  \
# 0       does_not_trouble_others_with    keeps_his_feelings_to_himself
# 317    makes_the_first_move_sexually            takes_the_lead_in_bed
# 2      puts_the_lives_of_others_over   puts_the_needs_and_feelings_of
# 1         is_financially_independent   is_able_to_provide_financially
# 8       shows_sportsmanship_and_does   helps_other_men_to_be_good_men
# 321   is_ready_to_use_physical_force   may_take_a_beating_of_whatever
# 38                       has_a_penis                     conservative
# 6      puts_his_bonds_with_other_men   does_man_s_work_and_lets_women
# 7     may_take_a_beating_of_whatever  maintains_his_physical_strength
# 42    helps_other_men_to_be_good_men           channels_his_anger_and
# 13                       has_a_penis              dresses_practically
# 52        has_the_confidence_that_if  will_defend_his_integrity_if_it
# 14                   speaks_his_mind  will_defend_his_integrity_if_it
# 90   accepts_survival_of_the_fittest   helps_other_men_to_be_good_men
# 37                          feminist      how_would_you_describe_your
# 310   is_ready_to_use_physical_force   does_man_s_work_and_lets_women
# 28     is_quick_to_respond_in_a_time       has_the_confidence_that_if
# 17    does_man_s_work_and_lets_women                      has_a_penis
# 49     is_always_keen_to_explore_and      is_willing_to_challenge_the
# 61      appreciates_beauty_in_all_of  cultivates_as_many_interests_as
# 40     is_quick_to_respond_in_a_time     shows_sportsmanship_and_does
# 51                   speaks_his_mind       is_unashamed_of_his_sexual
# 10   maintains_his_physical_strength    is_quick_to_respond_in_a_time
# 11                   speaks_his_mind          prioritises_clarity_and
# 59   does_not_let_his_feelings_cloud          prioritises_clarity_and
# 26    is_willing_to_endure_suffering   has_a_cause_he_believes_in_and
# 19    is_ready_to_use_physical_force    powers_through_a_problem_when
# 22   is_open_clear_and_consistent_in     settles_disputes_by_applying
# 275                      has_a_penis     is_secure_in_his_convictions
# 64      appreciates_beauty_in_all_of     does_not_speak_ill_of_others
# ..                               ...                              ...
# 274            takes_the_lead_in_bed     does_not_make_demands_of_his
# 77    may_take_a_beating_of_whatever  does_not_let_his_feelings_cloud
# 81      shows_sportsmanship_and_does  is_open_clear_and_consistent_in
# 301   would_rather_try_and_fail_than  cultivates_practical_skills_and
# 309                      libertarian     is_secure_in_his_convictions
# 237    puts_his_bonds_with_other_men     does_not_speak_ill_of_others
# 312      eats_whatever_food_he_wants   does_not_need_to_prove_himself
# 192     appreciates_beauty_in_all_of   does_not_need_to_prove_himself
# 277    puts_the_lives_of_others_over      has_the_confidence_to_speak
# 280  is_quick_to_form_an_opinion_and            men_s_rights_activist
# 281                          liberal                        anarchist
# 282    seeks_advice_when_he_wants_to     does_what_he_says_he_will_do
# 284                     conservative           channels_his_anger_and
# 285                      has_a_penis                where_do_you_live
# 286    puts_his_bonds_with_other_men              dresses_practically
# 287                      egalitarian     settles_disputes_by_applying
# 288  accepts_survival_of_the_fittest  values_competition_and_embraces
# 289      eats_whatever_food_he_wants  always_looks_to_improve_himself
# 200   is_able_to_provide_financially                     does_not_lie
# 291   may_take_a_beating_of_whatever      protects_those_who_are_less
# 305      eats_whatever_food_he_wants                     does_not_lie
# 290         is_faithful_to_his_roots                 what_is_your_age
# 292   is_willing_to_endure_suffering  accepts_survival_of_the_fittest
# 294         is_faithful_to_his_roots          prioritises_clarity_and
# 295    is_always_keen_to_explore_and       uses_his_wealth_and_social
# 298  cultivates_practical_skills_and           knows_everything_about
# 299            takes_the_lead_in_bed   has_a_cause_he_believes_in_and
# 304    is_always_keen_to_explore_and             does_not_let_fear_or
# 306      how_would_you_describe_your   puts_the_needs_and_feelings_of
# 320  shows_courtesy_by_holding_doors                     does_not_lie
#
#       strength
# 0   -50.230709
# 317 -33.889476
# 2   -31.959252
# 1   -30.401168
# 8   -24.584942
# 321 -24.503627
# 38  -19.593887
# 6   -18.712821
# 7   -15.963082
# 42  -14.513846
# 13  -14.386426
# 52  -13.961716
# 14  -13.468596
# 90  -13.133771
# 37  -12.926302
# 310 -12.762119
# 28  -12.646555
# 17  -12.475146
# 49  -12.254658
# 61  -12.225622
# 40  -12.108509
# 51  -11.997908
# 10  -11.786960
# 11  -11.741169
# 59  -10.833038
# 26  -10.566566
# 19  -10.348191
# 22   -9.971329
# 275  -9.883845
# 64   -9.811162
# ..         ...
# 274  -0.451307
# 77   -0.428807
# 81   -0.418927
# 301  -0.412752
# 309  -0.409791
# 237  -0.401836
# 312  -0.384996
# 192  -0.369674
# 277  -0.345221
# 280  -0.290521
# 281  -0.285705
# 282  -0.274928
# 284  -0.273755
# 285  -0.251010
# 286  -0.247965
# 287  -0.240692
# 288  -0.239404
# 289  -0.214199
# 200  -0.197418
# 291  -0.190824
# 305  -0.188653
# 290  -0.184700
# 292  -0.168726
# 294  -0.148955
# 295  -0.148680
# 298  -0.096702
# 299  -0.096657
# 304  -0.057261
# 306  -0.032793
# 320  -0.000395
#
# [322 rows x 3 columns]

# %%
import plotly.plotly as py
from plotly.graph_objs import *
import networkx as nx

# %%
log_positive_str = np.log(np.abs(str_df["strength"]))
log_positive_str = log_positive_str - min(log_positive_str) +1
log_positive_str.hist(bins=20)

# %%
G = nx.DiGraph( )
for i in str_df.index:
    if log_positive_str.loc[i] > 11: # filter weak links
        G.add_node( str_df.loc[i]["from"] )
        G.add_node( str_df.loc[i]["to"]   )
        G.add_edge( str_df.loc[i]["from"] , str_df.loc[i]["to"] , weight=log_positive_str.loc[i] )

# %%
plt.figure(figsize=(20,20));
pos=nx.spring_layout(G,weight='weight')
nx.draw(G,pos, with_labels=True)

# %%
import json
from networkx.readwrite import json_graph

for n in G:
    G.node[n]['name'] = n

d = json_graph.node_link_data(G)
json.dump(d, open('man-force/force.json','w'))

# %%
# helper to load url
# runs webserver and loads url with webbrowswer module
import sys

def load_url(path):
    PORT = 8001
    httpd = StoppableHTTPServer(("127.0.0.1",PORT), handler)
    thread.start_new_thread(httpd.serve, ())
    webbrowser.open_new('http://localhost:%s/%s'%(PORT,path))
    input("Press <RETURN> to stop server\n")
    httpd.stop()
    print("To restart server run: \n%s"%server)


if sys.version_info[0] == 2:
    import SimpleHTTPServer, BaseHTTPServer
    import socket
    import thread
    import webbrowser
    handler = SimpleHTTPServer.SimpleHTTPRequestHandler
    input = raw_input
    server = "python -m SimpleHTTPServer 8000"

    class StoppableHTTPServer(BaseHTTPServer.HTTPServer):

        def server_bind(self):
            BaseHTTPServer.HTTPServer.server_bind(self)
            self.socket.settimeout(1)
            self.run = True

        def get_request(self):
            while self.run:
                try:
                    sock, addr = self.socket.accept()
                    sock.settimeout(None)
                    return (sock, addr)
                except socket.timeout:
                    pass

        def stop(self):
            self.run = False

        def serve(self):
            while self.run:
                self.handle_request()


else:
    import http.server, http.server
    import socket
    import _thread as thread
    import webbrowser
    handler = http.server.SimpleHTTPRequestHandler
    server = "python -m http.server 8000"

    class StoppableHTTPServer(http.server.HTTPServer):

        def server_bind(self):
            http.server.HTTPServer.server_bind(self)
            self.socket.settimeout(1)
            self.run = True

        def get_request(self):
            while self.run:
                try:
                    sock, addr = self.socket.accept()
                    sock.settimeout(None)
                    return (sock, addr)
                except socket.timeout:
                    pass

        def stop(self):
            self.run = False

        def serve(self):
            while self.run:
                self.handle_request()

# %%
load_url('man-force/force.html')
# Out:
# 127.0.0.1 - - [02/Jan/2017 21:03:46] "GET /man-force/force.html HTTP/1.1" 200 -
# 127.0.0.1 - - [02/Jan/2017 21:03:46] "GET /man-force/force.js HTTP/1.1" 200 -
# 127.0.0.1 - - [02/Jan/2017 21:03:46] "GET /man-force/force.json HTTP/1.1" 200 -
# Press <RETURN> to stop server
#
# To restart server run:
# python -m http.server 8000

# %%
import os
cwd = os.getcwd()

# %%
cwd
# Out:
# 'C:\\Users\\Marios\\Desktop\\The Man of 2017\\man_2017_code'
