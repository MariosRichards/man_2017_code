# %%
import numpy as np
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt
import gc
import re

from sklearn import datasets
from sklearn.decomposition import PCA
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.preprocessing import StandardScaler

# %%
# %%time
# Load BES Panel for Wave 8
parsed_data = pd.read_pickle("man_of_2017_parsed.pkl")
#(31409, 733)

# BES_Panel = pd.read_stata("../BES_analysis_data/BES2015_W8_v1.6.dta")

print( parsed_data.shape )
# Out:
# (313, 83)
# Wall time: 13 ms

# %%
numerics_only = pd.DataFrame()
for col in parsed_data.columns:
    # drop object and datetime64[ns] silently
    if str( parsed_data[col].dtype ) == 'category':
        numerics_only[col] = parsed_data[col].cat.codes.astype('float')
    elif ( str( parsed_data[col].dtypes ) == 'bool') | ( str( parsed_data[col].dtypes ) == 'int64' ) :
        numerics_only[col] = parsed_data[col].astype('float')

# %%
non_ordinal = [ "how_would_you_describe_your" , "where_do_you_live" ]
pol_identity = parsed_data.columns[parsed_data.dtypes==bool]

# %%
parsed_data[ parsed_data.columns[parsed_data.dtypes==bool] ].sum()
# Out:
# socialist                163
# liberal                  181
# feminist                 210
# egalitarian              105
# libertarian               36
# anarchist                 24
# moderate                 104
# conservative              25
# men_s_rights_activist     10
# dtype: int64

# %%
temp = StandardScaler().fit_transform( numerics_only )
man_std = pd.DataFrame(temp,
                       columns = numerics_only.columns,
                       index   = numerics_only.index)
# man_std.drop(non_ordinal, axis=1,inplace=True)
# man_std.drop(pol_identity, axis=1,inplace=True)

# %%
# man_std.hist(figsize=(30,30))

# %%
# Leave = BES_std["euRefVote"]>0
# Stay =  BES_std["euRefVote"]<0

pca = PCA(n_components=2)
X_r = pca.fit(man_std).transform(man_std)

print( X_r.shape )

print('explained variance ratio (first two components): %s'
      % str(pca.explained_variance_ratio_) )

plt.figure(figsize=(6,6))
#plt.scatter( X_r[:, 0 ] ,X_r[:, 1 ] )

# Male, Female, Other
colour_array = ['b','r','g']
label_array = ["Man", "Woman", "Other"]
numerics_only["how_would_you_describe_your"]

for y in [0.0, 1.0, 2.0]:
    plt.scatter(X_r[ np.ix_(numerics_only["how_would_you_describe_your"]== y, [0]) ],
                X_r[ np.ix_(numerics_only["how_would_you_describe_your"] ==y, [1]) ],
                c    = colour_array[int(y)],
                label = label_array[int(y)] )
# plt.scatter( X_r[ np.ix_(Leave, [0]) ] , X_r[ np.ix_(Leave, [1]) ], c='r', label="Leave" )
# plt.scatter( X_r[ np.ix_(Stay , [0]) ] , X_r[ np.ix_(Stay , [1]) ], c='b', label="Stay"  )

plt.legend()
plt.title('PCA of Man 2017 dataset')
plt.show()
# Out:
# (313, 5)
# explained variance ratio (first two components): [ 0.15913563  0.07136959  0.0343961   0.02917577  0.0275431 ]

# %%
comp_0 = pd.DataFrame([ pca.components_[0], man_std.columns ]).T
comp_0[0].hist(bins=30)
# comp_0_vars = comp_0[comp_0[0].abs()>.12].sort_values(by=0).index
comp_0[comp_0[0].abs()>.04].sort_values(by=0)
# Out:
#             0                                1
# 72  -0.124051                         feminist
# 0  -0.0715259      how_would_you_describe_your
# 70 -0.0596694                        socialist
# 3  -0.0435291     do_you_believe_that_a_secret
# 25  0.0413909    seeks_advice_when_he_wants_to
# 59  0.0431758      eats_whatever_food_he_wants
# 7   0.0497514     appreciates_beauty_in_all_of
# 60  0.0543584   puts_the_needs_and_feelings_of
# 78  0.0547274            men_s_rights_activist
# 40  0.0578584   does_not_need_to_prove_himself
# 67  0.0608188     does_not_speak_ill_of_others
# 31   0.073395    puts_the_lives_of_others_over
# 23  0.0746051    is_willing_and_able_to_please
# 64  0.0758573         cherishes_and_values_the
# 5   0.0771972  cultivates_as_many_interests_as
# 45  0.0783086  is_quick_to_form_an_opinion_and
# 66  0.0797124   helps_other_men_to_be_good_men
# 24   0.081571     does_not_make_demands_of_his
# 77  0.0885792                     conservative
# 22  0.0926054       is_unashamed_of_his_sexual
# 69  0.0927429             lives_in_the_present
# 39   0.094562           channels_his_anger_and
# 48  0.0950772    makes_the_first_move_sexually
# 6   0.0969557           knows_everything_about
# 47  0.0976141    is_comfortable_with_who_he_is
# 50  0.0977202    keeps_his_feelings_to_himself
# 37   0.098995                     does_not_lie
# 68   0.101134         is_faithful_to_his_roots
# 46   0.104922    is_always_keen_to_explore_and
# 62   0.108999     is_secure_in_his_convictions
# ..        ...                              ...
# 36   0.122951   has_a_cause_he_believes_in_and
# 29   0.122982    powers_through_a_problem_when
# 15   0.124712  always_looks_to_improve_himself
# 43   0.130313  is_open_clear_and_consistent_in
# 21   0.130989           doesn_t_let_the_little
# 9    0.132214     does_what_he_says_he_will_do
# 11   0.132989  shows_courtesy_by_holding_doors
# 13   0.133009      protects_those_who_are_less
# 19   0.134104     settles_disputes_by_applying
# 4    0.135115       has_the_confidence_that_if
# 41   0.137093          prioritises_clarity_and
# 49   0.139439                      has_a_penis
# 57   0.144212              dresses_practically
# 65    0.14448  will_defend_his_integrity_if_it
# 44   0.147031     does_not_trouble_others_with
# 26   0.148531    does_not_rely_on_the_kindness
# 51   0.149404      has_the_confidence_to_speak
# 33   0.150243   would_rather_try_and_fail_than
# 56   0.151211   is_able_to_provide_financially
# 28   0.152834             does_not_let_fear_or
# 63   0.153152   is_ready_to_use_physical_force
# 20   0.153993       is_financially_independent
# 34   0.157074  has_a_plan_to_get_or_do_what_it
# 61   0.157364  does_not_let_his_feelings_cloud
# 18   0.157457                  speaks_his_mind
# 10   0.159969   may_take_a_beating_of_whatever
# 30   0.160672  cultivates_practical_skills_and
# 12   0.161612   is_willing_to_endure_suffering
# 27   0.173575    is_quick_to_respond_in_a_time
# 32   0.182439  maintains_his_physical_strength
#
# [71 rows x 2 columns]

# %%
comp_1 = pd.DataFrame([ pca.components_[1], man_std.columns ]).T
comp_1[0].hist(bins=30)
comp_1_vars = comp_1[comp_1[0].abs()>.09].sort_values(by=0).index
comp_1[comp_1[0].abs()>.09].sort_values(by=0)
# Out:
#             0                                1
# 8   -0.244055       uses_his_wealth_and_social
# 66   -0.23999   helps_other_men_to_be_good_men
# 25   -0.23383    seeks_advice_when_he_wants_to
# 7    -0.21253     appreciates_beauty_in_all_of
# 64  -0.187605         cherishes_and_values_the
# 17  -0.176208     shows_sportsmanship_and_does
# 67  -0.158555     does_not_speak_ill_of_others
# 72  -0.153231                         feminist
# 37  -0.152462                     does_not_lie
# 9   -0.144241     does_what_he_says_he_will_do
# 40  -0.142888   does_not_need_to_prove_himself
# 47  -0.139226    is_comfortable_with_who_he_is
# 38  -0.137656       cultivates_a_good_sense_of
# 14  -0.130779     arrives_to_occasions_on_time
# 15  -0.129022  always_looks_to_improve_himself
# 43  -0.128513  is_open_clear_and_consistent_in
# 39  -0.126576           channels_his_anger_and
# 13  -0.121719      protects_those_who_are_less
# 5    -0.12096  cultivates_as_many_interests_as
# 70  -0.118065                        socialist
# 46  -0.115227    is_always_keen_to_explore_and
# 60  -0.104453   puts_the_needs_and_feelings_of
# 16  -0.103968      is_willing_to_challenge_the
# 23  -0.103889    is_willing_and_able_to_please
# 0  -0.0973811      how_would_you_describe_your
# 54   0.102281         worth_is_measured_by_his
# 41   0.110468          prioritises_clarity_and
# 61   0.116776  does_not_let_his_feelings_cloud
# 29   0.117031    powers_through_a_problem_when
# 48   0.118507    makes_the_first_move_sexually
# 49   0.131481                      has_a_penis
# 44   0.138223     does_not_trouble_others_with
# 63   0.138256   is_ready_to_use_physical_force
# 58   0.142246            takes_the_lead_in_bed
# 45   0.159129  is_quick_to_form_an_opinion_and
# 26   0.159221    does_not_rely_on_the_kindness
# 53   0.161455  accepts_survival_of_the_fittest
# 52   0.176758    puts_his_bonds_with_other_men
# 55   0.188183   does_man_s_work_and_lets_women
# 50   0.210014    keeps_his_feelings_to_himself

# %%
import numpy as np
from sklearn.cluster import MeanShift, estimate_bandwidth
from sklearn.datasets.samples_generator import make_blobs


X = X_r


# The following bandwidth can be automatically detected using
bandwidth = estimate_bandwidth(X, quantile=0.2, n_samples=500)

ms = MeanShift(bandwidth=bandwidth, bin_seeding=True)
ms.fit(X)
labels = ms.labels_
cluster_centers = ms.cluster_centers_

labels_unique = np.unique(labels)
n_clusters_ = len(labels_unique)

print("number of estimated clusters : %d" % n_clusters_)


import matplotlib.pyplot as plt
from itertools import cycle

plt.figure(1)
plt.clf()

colors = cycle('bgrcmykbgrcmykbgrcmykbgrcmyk')
for k, col in zip(range(n_clusters_), colors):
    my_members = labels == k
    cluster_center = cluster_centers[k]
    plt.plot(X[my_members, 0], X[my_members, 1], col + '.')
    plt.plot(cluster_center[0], cluster_center[1], 'o', markerfacecolor=col,
             markeredgecolor='k', markersize=14)
plt.title('Estimated number of clusters: %d' % n_clusters_)
plt.show()
# Out:
# number of estimated clusters : 5

# %%
X_r.shape
# Out:
# (313, 10)
